# %% [markdown]
# For Analysis of Calculations
# Run this script first!
# It will produce folders named \<iso-date\>_analysis_output_vx.py
# The calculations are the same as in phenometrics.py. The output of this script is the used in the script
# phenometrics_pixel_to_graph.ipynb.

# %%
import os
import numpy as np
import pandas as pd
import concurrent.futures
import rasterio
from scipy.interpolate import splrep, BSpline
from sklearn.linear_model import LinearRegression
from datetime import datetime

# %%
# Constants
SMOOTH = 0.05
THRESHOLD_ = 90 # can be set to None
THRESHOLD_SOWING_MIN = 150
THRESH_END = 250


# select with these three constants which vertical pixelstack will be analized. 
# Do not select too many pixels!!
LOAD_MIN_COL = 705
LOAD_MAX_COL = LOAD_MIN_COL + 1
LOAD_MIN_ROW = 436
LOAD_MAX_ROW = 443

# %%
ndvi_stack, doys, valid_image_area_mask, meta = load_ndvi_stack('./S2_clip_new/')
# Out:
# Loading NDVI stack from ./S2_clip_new/

# %%
valid_image_area_mask.shape
# Out:
# (7, 1)

# %%
def load_ndvi_stack(directory, filter_threshold=THRESHOLD_):
    """
    Load NDVI stack from a directory containing NDVI images.
    The threshold is set from the constants if not set manually to an int between 0 and 365.
    A two dimensional mask is returned that is true for all pixels that hold at least one value 
    """
    print('Loading NDVI stack from', directory)
    # TODO: shouldn't the first dataset below the threshold be taken into consideration?

    file_paths = sorted([os.path.join(directory, fp) for fp in os.listdir(directory) if fp.endswith('.tif')])
    
    def sort_by_doy(file_paths):
        fps = np.array(file_paths)
        fp_doys = np.array([os.path.basename(fp).split('_')[-2].split('.')[0] for fp in fps])
        sorted_indices = np.argsort(fp_doys)
        return fps[sorted_indices]
    
    file_paths = sort_by_doy(file_paths)
    
    doys = np.array([int(os.path.basename(fp).split('_')[-2].split('.')[0]) for fp in file_paths], dtype=np.int64)
    
    if filter_threshold is not None:
        file_paths = [fp for fp in file_paths if int(os.path.basename(fp).split('_')[-2].split('.')[0]) >= filter_threshold]
        doys = np.array([int(os.path.basename(fp).split('_')[-2].split('.')[0]) for fp in file_paths], dtype=np.int64)

    ndvi_stack = []
    mask_stack = []
       
    for fp in file_paths:
        with rasterio.open(fp) as dataset:
            ndvi_data = dataset.read(1).astype(np.float64)
            ndvi_stack.append(ndvi_data[LOAD_MIN_ROW:LOAD_MAX_ROW, LOAD_MIN_COL:LOAD_MAX_COL])
            # ndvi_stack.append(ndvi_data)
            
            mask_stack.append(np.isnan(ndvi_data[LOAD_MIN_ROW:LOAD_MAX_ROW, LOAD_MIN_COL:LOAD_MAX_COL]))
    with rasterio.open(file_paths[0]) as dataset:
        meta = dataset.meta

    ndvi_stack = np.array(ndvi_stack)
    mask_stack = np.array(mask_stack)

    valid_image_area_mask = ~np.any(mask_stack, axis=0)
    if len(doys) < 3:
        raise ValueError(f'Not enough images in the stack (less than 3!) in directory {directory} with threshold {filter_threshold}')
    
    return ndvi_stack, doys, valid_image_area_mask, meta

# %%
def find_max(doys, ndvi_values, THRESH_END):
    mask = doys <= THRESH_END
    filtered_doys = doys[mask]
    filtered_ndvi_values = ndvi_values[mask]
    max_index = np.argmax(filtered_ndvi_values)
    return filtered_doys[max_index], filtered_ndvi_values[max_index]

# %%
def filter_to_range_between_minima(fine_doys, b_spline, max_ndvi_doy):
    mask_sos = fine_doys < max_ndvi_doy
    mask_eos = fine_doys > max_ndvi_doy 
    print('filter_to_range_between_minima mask_sos', mask_sos, 'mask_eos', mask_eos)
    
    filtered_doys_sos = fine_doys[mask_sos]
    filtered_b_spline_sos = b_spline[mask_sos]
    print('filter_to_range_between_minima filtered_doys_sos', filtered_doys_sos)
    print('filter_to_range_between_minima filtered_b_spline_sos', filtered_b_spline_sos)
    
    filtered_doys_eos = fine_doys[mask_eos]
    filtered_b_spline_eos = b_spline[mask_eos]
    print('filter_to_range_between_minima filtered_doys_eos', filtered_doys_eos)
    print('filter_to_range_between_minima filtered_b_spline_eos', filtered_b_spline_eos)
    
    # indices of minimum NDVI values on both sides of max_ndvi_doy


    index_sos = None
    index_eos = None
    original_index_sos = 0
    original_index_eos = len(fine_doys) - 1
    if filtered_b_spline_sos.size > 0:
        index_sos = np.argmin(filtered_b_spline_sos)
        original_index_sos = np.where(fine_doys == filtered_doys_sos[index_sos])[0][0]
    print('filter_to_range_between_minima index_sos', index_sos)
    index_eos = np.argmin(filtered_b_spline_eos)
    if filtered_b_spline_eos.size > 0:
        print('filter_to_range_between_minima index_eos', index_eos)
        # Convert these indices back to the original indices
        
        print('filter_to_range_between_minima original_index_sos', original_index_sos)
        original_index_eos = np.where(fine_doys == filtered_doys_eos[index_eos])[0][0]
    print('filter_to_range_between_minima original_index_eos', original_index_eos)
    
    # subsets of fine_doys and b_spline between the two NDVI minima
    b_spline_new = b_spline[original_index_sos:(original_index_eos+1)]
    fine_doys_new = fine_doys[original_index_sos:(original_index_eos+1)]
    
    
    return fine_doys_new, b_spline_new

# %%
mask_sos = fine_doys < max_ndvi_doy
mask_eos = fine_doys > max_ndvi_doy 
filtered_doys_sos = fine_doys[mask_sos]
filtered_b_spline_sos = b_spline[mask_sos]
filtered_doys_eos = fine_doys[mask_eos]
filtered_b_spline_eos = b_spline[mask_eos]
index_sos = np.argmin(filtered_b_spline_sos)
filtered_b_spline_sos
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 7
#       5 filtered_doys_eos = fine_doys[mask_eos]
#       6 filtered_b_spline_eos = b_spline[mask_eos]
# ----> 7 index_sos = np.argmin(filtered_b_spline_sos)
#       8 filtered_b_spline_sos
#
# File ~/miniconda3/envs/.menv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:1325, in argmin(a, axis, out, keepdims)
#    1238 """
#    1239 Returns the indices of the minimum values along an axis.
#    1240
#    (...)
#    1322 (2, 1, 4)
#    1323 """
#    1324 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1325 return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#
# File ~/miniconda3/envs/.menv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: attempt to get argmin of an empty sequence

# %%
np.percentile(b_spline, 90)- np.percentile(b_spline, 10)
# Out:
# 0.10571576304631794

# %%
np.percentile(ndvi_values, 90)- np.percentile(ndvi_values, 10)
# Out:
# 0.195212022960186

# %%
def remove_nan(arr1, arr2):
    mask = ~np.isnan(arr2)
    return arr1[mask], arr2[mask]

# %%
def fit_linear_regression(fine_doys, b_spline, max_ndvi_doy):
    left_indices = fine_doys < max_ndvi_doy
    right_indices = fine_doys > max_ndvi_doy

    left_model = LinearRegression().fit(fine_doys[left_indices].reshape(-1, 1), b_spline[left_indices]) if np.any(left_indices) else None
    right_model = LinearRegression().fit(fine_doys[right_indices].reshape(-1, 1), b_spline[right_indices]) if np.any(right_indices) else None
    
    return left_model, right_model

# %%
def calculate_base(left_model, right_model):
    
    if left_model is not None and right_model is not None:
        return (left_model.coef_[0] + right_model.coef_[0]) / 2.0
    else:
        return None

# %%
def calculate_relative_amplitude(ndvi_values):
    return np.percentile(ndvi_values, 90) - np.percentile(ndvi_values, 10)

# %%
def convert_to_serializable(obj):
    if obj is np.nan:
        return None
    if isinstance(obj, np.generic):
        return obj.item()
    return obj

# %%
def calculate_sos_eos(fine_doys, b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude):
    """
    Calculations are split into sos - start of season and eos - end of season.
    Those timeranges are defined by the maximum NDVI value in the seaseon.
    """
    sos_mask = fine_doys < max_ndvi_doy
    print(' sos_mask = fine_doys < max_ndvi_doy', sos_mask)
    eos_mask = fine_doys > max_ndvi_doy
    print('eos_mask = fine_doys > max_ndvi_doy', eos_mask)
    sos_doys = fine_doys[sos_mask]
    print('sos_doys', sos_doys)
    eos_doys = fine_doys[eos_mask]
    print('eos_doys', eos_doys)
    sos_ndvi_values = b_spline[sos_mask]
    eos_ndvi_values = b_spline[eos_mask]

    seasonal_amplitude = base + 0.25 * amplitude 
    len_sos_ndvi_values = True
    len_eos_ndvi_values = True
    
    # SoS calculations
    if len(sos_ndvi_values) > 0:
        sos_min_value = np.min(sos_ndvi_values)
        threshold_sos = sos_min_value + 0.1 * (max_ndvi_value - sos_min_value)
        #TODO Genaugenommen müsste hier der np.abs wegfallen, weil ABOVE thrs
        # JETZT ERSETZT DURCH first_of_slope10_sos2
        # first_of_slope10_sos = sos_doys[np.argmin(np.abs(sos_ndvi_values - threshold_sos))]
        
        sos_diff = sos_ndvi_values - threshold_sos
        positive_sos_diff = sos_diff[sos_diff > 0]
        if len(positive_sos_diff) > 0:
        # TODO delete this or first_of-slope10_sos
            first_of_slope10_sos2_doy = sos_doys[sos_diff > 0][np.argmin(sos_diff[sos_diff > 0])]
        else:
            first_of_slope10_sos2_doy = np.nan
            # print(f'Pixel first_of_slope10_sos2_doy is nan')
        
        median_ndvi_sos = np.median(sos_ndvi_values)
        sos_median_diff = sos_ndvi_values - median_ndvi_sos
        median_of_slope_sos_doy = sos_doys[np.argmin(np.abs(sos_ndvi_values - median_ndvi_sos))] 
         
        seasonal_amplitude_doy_sos = sos_doys[np.argmin(np.abs(sos_ndvi_values - seasonal_amplitude))]
        
        relative_amplitude_sos_old = calculate_relative_amplitude(sos_ndvi_values)
        relative_amplitude_doy_sos_old_idx = np.argmin(np.abs(sos_ndvi_values - relative_amplitude_sos_old))
        relative_amplitude_doy_sos_old = sos_doys[relative_amplitude_doy_sos_old_idx]
        if relative_amplitude_doy_sos_old_idx == 0:
            relative_amplitude_doy_sos_old = np.nan


        # relative to the overall amplitude
        
        dists_from_relative_amplitude = abs(sos_ndvi_values - overall_relative_amplitude)
        idx_relative_amplitude = np.argmin(dists_from_relative_amplitude)
        if idx_relative_amplitude > 0:
            relative_amplitude_doy_sos = sos_doys[idx_relative_amplitude]
        else:
            relative_amplitude_doy_sos = np.nan

    else:
        len_sos_ndvi_values = False
        # first_of_slope10_sos = np.nan
        first_of_slope10_sos2_doy = np.nan
        median_of_slope_sos_doy = np.nan
        seasonal_amplitude_doy_sos = np.nan
        relative_amplitude_doy_sos = np.nan
        relative_amplitude_doy_sos_old = np.nan

    # EoS calculations
    if len(eos_ndvi_values) > 0:
        eos_min_value = np.min(eos_ndvi_values)
        threshold_eos = eos_min_value + 0.1 * (max_ndvi_value - eos_min_value)
        # Siehe oben!
        # first_of_slope10_eos = eos_doys[np.argmin(np.abs(eos_ndvi_values - threshold_eos))]

        eos_diff = eos_ndvi_values - threshold_eos
        positive_eos_diff = eos_diff[eos_diff < 0]
        if len(positive_eos_diff) > 0:
        # TODO delete this or first_of-slope10_sos
            first_of_slope10_eos2_doy = eos_doys[eos_diff < 0][np.argmax(eos_diff[eos_diff < 0])]
        else:
            first_of_slope10_eos2_doy = np.nan
            # print(f'Pixel first_of_slope10_eos2 is nan')
        
        median_ndvi_eos = np.median(eos_ndvi_values)
        eos_median_diff = eos_ndvi_values - median_ndvi_eos
        
        median_of_slope_eos_doy = eos_doys[np.argmin(np.abs(eos_ndvi_values - median_ndvi_eos))]
        
        
        seasonal_amplitude_doy_eos = eos_doys[np.argmin(np.abs(eos_ndvi_values - seasonal_amplitude))]
        
        # old relative amplitude
        relative_amplitude_eos_old = calculate_relative_amplitude(eos_ndvi_values)
        relative_amplitude_eos_old_idx = np.argmin(np.abs(eos_ndvi_values - relative_amplitude_eos_old))
        relative_amplitude_doy_eos_old = eos_doys[relative_amplitude_eos_old_idx]
        if relative_amplitude_eos_old_idx == 0:
            relative_amplitude_doy_eos_old = np.nan

        # relative to the overall amplitude
        dists_from_relative_amplitude = abs(eos_ndvi_values - overall_relative_amplitude)  
        idx_relative_amplitude = np.argmin(dists_from_relative_amplitude)
        if idx_relative_amplitude > 0:
            relative_amplitude_doy_eos = eos_doys[idx_relative_amplitude]
        else:
            relative_amplitude_doy_eos = np.nan
    else:
        len_eos_ndvi_values = False
        first_of_slope10_eos2_doy = np.nan
        median_of_slope_eos_doy = np.nan
        seasonal_amplitude_doy_eos = np.nan
        relative_amplitude_doy_eos = np.nan
        relative_amplitude_doy_eos_old = np.nan
    
    return {
        'seasonal_amplitude': convert_to_serializable(seasonal_amplitude) if np.any(seasonal_amplitude) else None,
        'len_sos_ndvi_values': convert_to_serializable(len_sos_ndvi_values) if np.any(len_sos_ndvi_values) else None,
        'len_eos_ndvi_values': convert_to_serializable(len_eos_ndvi_values) if np.any(len_eos_ndvi_values) else None,
        'sos_mask': list(convert_to_serializable(sos_mask)) if np.any(sos_mask) else None,
        'eos_mask': list(convert_to_serializable(eos_mask)) if np.any(eos_mask) else None,
        'sos_doys': list(convert_to_serializable(sos_doys)) if np.any(sos_doys) else None,
        'eos_doys': list(convert_to_serializable(eos_doys)) if np.any(eos_doys) else None,
        'sos_ndvi_values': list(convert_to_serializable(sos_ndvi_values)) if np.any(sos_ndvi_values) else None,
        'eos_ndvi_values': list(convert_to_serializable(eos_ndvi_values)) if np.any(eos_ndvi_values) else None,
        'sos_threshold': convert_to_serializable(threshold_sos) if np.any(threshold_sos) else None,
        'sos_median_ndvi': convert_to_serializable(median_ndvi_sos) if np.any(median_ndvi_sos) else None,
        'sos_median_diff': list(convert_to_serializable(sos_median_diff)) if np.any(sos_median_diff) else None,
        'sos_first_of_slope_doy': convert_to_serializable(first_of_slope10_sos2_doy) if np.any(first_of_slope10_sos2_doy) else None, 
        'sos_median_of_slope_doy': convert_to_serializable(median_of_slope_sos_doy) if np.any(median_of_slope_sos_doy) else None, 
        'sos_seasonal_amplitude_doy': convert_to_serializable(seasonal_amplitude_doy_sos) if np.any(seasonal_amplitude_doy_sos) else None, 
        'sos_relative_amplitude_doy': convert_to_serializable(relative_amplitude_doy_sos) if np.any(relative_amplitude_doy_sos) else None,
        'sos_relative_amplitude_doy_old': convert_to_serializable(relative_amplitude_doy_sos_old) if np.any(relative_amplitude_doy_sos_old) else None,
        'eos_threshold': convert_to_serializable(threshold_eos) if np.any(threshold_eos) else None,
        'eos_median_ndvi': convert_to_serializable(median_ndvi_eos) if np.any(median_ndvi_eos) else None,
        'eos_median_diff': list(convert_to_serializable(eos_median_diff)) if np.any(eos_median_diff) else None,
        'eos_first_of_slope_doy': convert_to_serializable(first_of_slope10_eos2_doy) if np.any(first_of_slope10_eos2_doy) else None,
        'eos_median_of_slope_doy': convert_to_serializable(median_of_slope_eos_doy) if np.any(median_of_slope_eos_doy) else None,
        'eos_seasonal_amplitude_doy': convert_to_serializable(seasonal_amplitude_doy_eos) if np.any(seasonal_amplitude_doy_eos) else None,
        'eos_relative_amplitude_doy': convert_to_serializable(relative_amplitude_doy_eos) if np.any(relative_amplitude_doy_eos) else None,
        'eos_relative_amplitude_doy_old': convert_to_serializable(relative_amplitude_doy_eos_old) if np.any(relative_amplitude_doy_eos_old) else None,
    }

# %%
def process_pixel(row, col, ndvi_values, doys, num_cols):
    """
    1. Nan values in the pixel are removed
    2. Spline function is determined
    3. the overall relative amplitude is determined
    4. The result for one pixel is completed with the values from sos_eos_calculate    
    """
    print('process_pixel ', row, col, ndvi_values, doys, num_cols)

    # if there are invalid values, they are taken out of the ndvi_values and doys
    isnan_mask = np.isnan(ndvi_values)
    print('isnan mask (should not all be True)', isnan_mask)
    
    if np.any(isnan_mask):
        print('nan values ')
        ndvi_values = ndvi_values[~isnan_mask]
        doys = doys[~isnan_mask]
    if np.any(~isnan_mask):
        print('no ndvi values are nan')

    # create an array with all doys in the timerange
    min_doy, max_doy = min(doys), max(doys)
    print('min doy:', min_doy, 'max doy:', max_doy)
    fine_doys = np.linspace(min_doy, max_doy, max_doy - min_doy + 1, dtype=int)
    

    tck_spline = splrep(doys, ndvi_values, s=SMOOTH)
    print('tck_spline', tck_spline)
    b_spline = BSpline(*tck_spline)(fine_doys)
    # print('b_spline', b_spline)
    # print('fine_doys 1', fine_doys)
    max_ndvi_doy, max_ndvi_value = find_max(fine_doys, b_spline, THRESH_END)
    print('max_ndvi_doy, max_ndvi_value', max_ndvi_doy, max_ndvi_value)

    #limit the doy interval to the range between the sos and eos minimum
    fine_doys, b_spline = filter_to_range_between_minima(fine_doys, b_spline, max_ndvi_doy)
    # print('fine_doys after filter', fine_doys, '\nb_spline', b_spline )
    
     
    # print('fine_doys 2 at ',row, col, ':\n', fine_doys)


    left_model, right_model = fit_linear_regression(fine_doys, b_spline, max_ndvi_doy)
    # base = calculate_base(left_model, right_model)
    # amplitude = max_ndvi_value - base
    ##### !!!!!!!!!!!!!!!!! NEW !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    base = None
    amplitude = None
    # new amplitude calculation: NDVI max - (Eos Min + Sos Min / 2)
    if np.any(fine_doys < max_ndvi_doy) and np.any(fine_doys > max_ndvi_doy):
        base = (min(ndvi_values[fine_doys < max_ndvi_doy]) + min(ndvi_values[fine_doys > max_ndvi_doy])) / 2
        amplitude = max_ndvi_value - base
    
    
    

    overall_relative_amplitude = calculate_relative_amplitude(ndvi_values)


    sos_eos_dict = calculate_sos_eos(fine_doys,  b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude)
    print('sos_eos_dict 1: ', sos_eos_dict)

    


    sos_eos_dict.update({'row': LOAD_MIN_ROW + row, 
                        'col': LOAD_MIN_COL + col, 
                        'org_ndvi_values': list(ndvi_values), 
                        'org_ndvi_doys': list(doys),
                        'min_doy': convert_to_serializable(min_doy), 
                        'max_doy': convert_to_serializable(max_doy), 
                        'max_ndvi_doy': convert_to_serializable(max_ndvi_doy), 
                        'max_ndvi_value': convert_to_serializable(max_ndvi_value),
                        'fine_doys': list(fine_doys),
                        'b_spline': list(b_spline),
                        'base': convert_to_serializable(base),
                    'amplitude': convert_to_serializable(amplitude),
                    'overall_relative_amplitude': convert_to_serializable(overall_relative_amplitude),
                    'left_model': left_model.get_params() if left_model is not None else None,
                    'right_model': right_model.get_params() if right_model is not None else None,
                    'left_model_coef': left_model.coef_[0] if left_model is not None else None,
                    'right_model_coef': right_model.coef_[0] if right_model is not None else None,
                    'left_model_intercept': left_model.intercept_ if left_model is not None else None,
                    'right_model_intercept': right_model.intercept_ if right_model is not None else None,
                    })
    print('sos_eos_dict after update: ', sos_eos_dict)
    return sos_eos_dict

# %%
def save_geotiff(data, meta, file_path):
    
    meta.update(dtype=rasterio.float32, count=1)
    with rasterio.open(file_path, 'w', **meta) as dst:
        dst.write(data.astype(rasterio.float32), 1)

# %%
# No Threading etc - 69minutes
def process_stack(input_dir):
    """Main function to process NDVI data."""
    print(f'Start processing {input_dir}')
    start = datetime.now()
    current_date = datetime.now().date().isoformat()

    def make_directory(input_dir, counter=1):
        output_dir = os.path.join(os.path.dirname(os.path.dirname(input_dir)), f'{current_date}_analysis_output_v{counter}')
        if os.path.exists(output_dir):
            return make_directory(input_dir, counter + 1)
        else:
            os.makedirs(output_dir)
        return output_dir

    output_dir = make_directory(input_dir)

   
    ndvi_stack, doys, mask, meta = load_ndvi_stack(input_dir)
    num_rows, num_cols = ndvi_stack[0].shape
    # print(input_dir, ndvi_stack[0].shape)
    # Ensure sos_eos_data has enough depth to store all keys from the dictionary
        
    for row in range(num_rows):
        for col in range(num_cols):
            if mask[row, col]:
                # try:  
                sos_eos_dict = process_pixel(row, col, ndvi_stack[:, row, col], doys, num_cols)
                # print('sos_eos_dict', sos_eos_dict)
                with open(os.path.join(output_dir, f'S2_{LOAD_MIN_ROW + row}_{LOAD_MIN_COL + col}.py'), 'a') as f:
                    f.write('ndvi_dict = {\n')
                    for key, value in sos_eos_dict.items():
                        f.write(f'    "{key}": {value},\n')   
                    f.write('}\n')
                # except Exception as e:
                #     print(f'Error processing pixel {row}, {col}: {e}')
                #     continue

               

    
    # An output folder is created at the same level as the input_dir. The output folder is named e.g. 2024-11-06_output.

# %%
process_stack('./S2_clip_new/')
# Out:
# Start processing ./S2_clip_new/
# Loading NDVI stack from ./S2_clip_new/
# process_pixel  0 0 [0.32519424 0.32625085 0.13020372 0.13749816 0.17107332 0.28943628
#  0.28671557 0.32630885 0.31999999 0.09559111 0.22640292 0.25859156] [106 108 156 161 173 201 206 221 223 273 296 301] 1
# isnan mask (should not all be True) [False False False False False False False False False False False False]
# no ndvi values are nan
# min doy: 106 max doy: 301
# tck_spline (array([106., 106., 106., 106., 206., 301., 301., 301., 301.]), array([0.31748365, 0.10205244, 0.28240577, 0.32063924, 0.19195555,
#        0.        , 0.        , 0.        , 0.        ]), 3)
# max_ndvi_doy, max_ndvi_value 106 0.31748364817251246
# filter_to_range_between_minima mask_sos [ True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False] mask_eos [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]
# filter_to_range_between_minima filtered_doys_sos [106]
# filter_to_range_between_minima filtered_b_spline_sos [0.31748365]
# filter_to_range_between_minima filtered_doys_eos [107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124
#  125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142
#  143 144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160
#  161 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178
#  179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196
#  197 198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214
#  215 216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232
#  233 234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250
#  251 252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268
#  269 270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286
#  287 288 289 290 291 292 293 294 295 296 297 298 299 300 301]
# filter_to_range_between_minima filtered_b_spline_eos [0.31111274 0.30492452 0.2989169  0.29308782 0.28743521 0.28195698
#  0.27665108 0.27151543 0.26654796 0.26174659 0.25710926 0.25263389
#  0.24831841 0.24416075 0.24015884 0.2363106  0.23261397 0.22906687
#  0.22566722 0.22241297 0.21930203 0.21633234 0.21350182 0.21080841
#  0.20825002 0.20582459 0.20353004 0.20136431 0.19932533 0.19741101
#  0.19561929 0.1939481  0.19239536 0.19095901 0.18963697 0.18842717
#  0.18732754 0.186336   0.18545049 0.18466893 0.18398926 0.18340939
#  0.18292726 0.18254079 0.18224792 0.18204658 0.18193468 0.18191016
#  0.18197095 0.18211497 0.18234016 0.18264444 0.18302574 0.18348198
#  0.18401111 0.18461103 0.18527969 0.18601501 0.18681493 0.18767735
#  0.18860023 0.18958147 0.19061902 0.1917108  0.19285474 0.19404877
#  0.19529081 0.19657879 0.19791065 0.1992843  0.20069769 0.20214873
#  0.20363535 0.20515549 0.20670706 0.20828801 0.20989625 0.21152972
#  0.21318634 0.21486405 0.21656076 0.21827442 0.22000294 0.22174425
#  0.22349629 0.22525698 0.22702425 0.22879603 0.23057024 0.23234482
#  0.23411769 0.23588678 0.23765002 0.23940534 0.24115066 0.24288391
#  0.24460303 0.24630594 0.24799056 0.24965484 0.2512969  0.25291574
#  0.25451056 0.25608058 0.25762499 0.259143   0.26063382 0.26209665
#  0.26353069 0.26493516 0.26630925 0.26765217 0.26896313 0.27024134
#  0.27148598 0.27269629 0.27387144 0.27501067 0.27611316 0.27717812
#  0.27820476 0.27919228 0.28013989 0.2810468  0.2819122  0.28273531
#  0.28351532 0.28425146 0.28494291 0.28558888 0.28618858 0.28674122
#  0.287246   0.28770213 0.2881088  0.28846523 0.28877062 0.28902418
#  0.2892251  0.28937261 0.28946589 0.28950416 0.28948663 0.28941248
#  0.28928095 0.28909121 0.28884249 0.28853399 0.28816491 0.28773446
#  0.28724184 0.28668626 0.28606693 0.28538304 0.2846338  0.28381842
#  0.28293611 0.28198607 0.2809675  0.27987961 0.2787216  0.27749268
#  0.27619206 0.27481894 0.27337253 0.27185202 0.27025663 0.26858556
#  0.26683802 0.2650132  0.26311033 0.26112859 0.2590672  0.25692537
#  0.25470229 0.25239717 0.25000922 0.24753764 0.24498163 0.24234042
#  0.23961318 0.23679915 0.23389751 0.23090747 0.22782824 0.22465903
#  0.22139903 0.21804746 0.21460351 0.2110664  0.20743534 0.20370951
#  0.19988813 0.19597041 0.19195555]
# filter_to_range_between_minima index_sos 0
# filter_to_range_between_minima index_eos 47
# filter_to_range_between_minima original_index_sos 0
# filter_to_range_between_minima original_index_eos 48
#  sos_mask = fine_doys < max_ndvi_doy [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# eos_mask = fine_doys > max_ndvi_doy [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# sos_doys []
# eos_doys [107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124
#  125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142
#  143 144 145 146 147 148 149 150 151 152 153 154]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 process_stack('./S2_clip_new/')
#
# Cell In[17], line 28, in process_stack(input_dir)
#      25 for col in range(num_cols):
#      26     if mask[row, col]:
#      27         # try:
# ---> 28         sos_eos_dict = process_pixel(row, col, ndvi_stack[:, row, col], doys, num_cols)
#      29         # print('sos_eos_dict', sos_eos_dict)
#      30         with open(os.path.join(output_dir, f'S2_{LOAD_MIN_ROW + row}_{LOAD_MIN_COL + col}.py'), 'a') as f:
#
# Cell In[15], line 60, in process_pixel(row, col, ndvi_values, doys, num_cols)
#      52     amplitude = max_ndvi_value - base
#      57 overall_relative_amplitude = calculate_relative_amplitude(ndvi_values)
# ---> 60 sos_eos_dict = calculate_sos_eos(fine_doys,  b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude)
#      61 print('sos_eos_dict 1: ', sos_eos_dict)
#      66 sos_eos_dict.update({'row': LOAD_MIN_ROW + row,
#      67                     'col': LOAD_MIN_COL + col,
#      68                     'org_ndvi_values': list(ndvi_values),
#    (...)
#      84                 'right_model_intercept': right_model.intercept_ if right_model is not None else None,
#      85                 })
#
# Cell In[14], line 17, in calculate_sos_eos(fine_doys, b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude)
#      14 sos_ndvi_values = b_spline[sos_mask]
#      15 eos_ndvi_values = b_spline[eos_mask]
# ---> 17 seasonal_amplitude = base + 0.25 * amplitude
#      18 len_sos_ndvi_values = True
#      19 len_eos_ndvi_values = True
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
ndvi_stack, doys, mask, meta = load_ndvi_stack('./S2_clip_new/')
num_rows, num_cols = ndvi_stack[0].shape
row = 0
col = 0
ndvi_values = ndvi_stack[:, 0, 0]
# Out:
# Loading NDVI stack from ./S2_clip_new/

# %%
ndvi_stack[:, 2, 0]
# Out:
# array([0.27793479, 0.28409895, 0.1505167 , 0.15961801, 0.20374283,
#        0.29538763, 0.29201752, 0.289583  , 0.26094627, 0.10281858,
#        0.21728188, 0.25809506])

# %%
doys
# Out:
# array([106, 108, 156, 161, 173, 201, 206, 221, 223, 273, 296, 301])

# %%
# process pixel
isnan_mask = np.isnan(ndvi_values)
isnan_mask
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
min_doy, max_doy = min(doys), max(doys)
min_doy, max_doy
# Out:
# (106, 301)

# %%
fine_doys = np.linspace(min_doy, max_doy, max_doy - min_doy + 1, dtype=int)
fine_doys
# Out:
# array([106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#        119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131,
#        132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144,
#        145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157,
#        158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170,
#        171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183,
#        184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196,
#        197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209,
#        210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222,
#        223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235,
#        236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248,
#        249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261,
#        262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274,
#        275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287,
#        288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300,
#        301])

# %%
ndvi_values = ndvi_values[2:]
doys= doys[2:]

# %%
tck_spline = splrep(doys, ndvi_values, s=0.005)
tck_spline
# Out:
# (array([106., 106., 106., 106., 206., 273., 301., 301., 301., 301.]),
#  array([ 0.34166568, -0.20275783,  0.61923432,  0.05290926,  0.14689662,
#          0.26342417,  0.        ,  0.        ,  0.        ,  0.        ]),
#  3)

# %%
b_spline = BSpline(*tck_spline)(fine_doys)
b_spline
# Out:
# array([0.34166568, 0.32564246, 0.31023219, 0.29542583, 0.28121436,
#        0.26758875, 0.25453996, 0.24205896, 0.23013671, 0.2187642 ,
#        0.20793238, 0.19763222, 0.1878547 , 0.17859078, 0.16983143,
#        0.16156761, 0.1537903 , 0.14649046, 0.13965907, 0.13328708,
#        0.12736548, 0.12188522, 0.11683728, 0.11221262, 0.10800222,
#        0.10419703, 0.10078804, 0.0977662 , 0.09512249, 0.09284787,
#        0.09093331, 0.08936979, 0.08814826, 0.0872597 , 0.08669508,
#        0.08644536, 0.08650151, 0.0868545 , 0.08749531, 0.08841489,
#        0.08960421, 0.09105425, 0.09275597, 0.09470035, 0.09687834,
#        0.09928092, 0.10189905, 0.10472371, 0.10774586, 0.11095648,
#        0.11434652, 0.11790695, 0.12162876, 0.1255029 , 0.12952034,
#        0.13367205, 0.137949  , 0.14234216, 0.14684249, 0.15144097,
#        0.15612856, 0.16089623, 0.16573495, 0.17063569, 0.17558941,
#        0.18058709, 0.18561968, 0.19067817, 0.19575352, 0.2008367 ,
#        0.20591867, 0.21099041, 0.21604288, 0.22106705, 0.22605389,
#        0.23099436, 0.23587944, 0.2407001 , 0.2454473 , 0.25011201,
#        0.2546852 , 0.25915783, 0.26352088, 0.26776532, 0.27188211,
#        0.27586222, 0.27969661, 0.28337627, 0.28689215, 0.29023523,
#        0.29339646, 0.29636683, 0.2991373 , 0.30169883, 0.3040424 ,
#        0.30615898, 0.30803953, 0.30967502, 0.31105641, 0.31217469,
#        0.31302081, 0.31358856, 0.31388299, 0.31391197, 0.31368337,
#        0.31320505, 0.31248488, 0.31153072, 0.31035045, 0.30895193,
#        0.30734303, 0.30553161, 0.30352555, 0.3013327 , 0.29896094,
#        0.29641814, 0.29371215, 0.29085086, 0.28784211, 0.28469379,
#        0.28141376, 0.27800989, 0.27449004, 0.27086207, 0.26713387,
#        0.26331329, 0.2594082 , 0.25542647, 0.25137597, 0.24726456,
#        0.24310011, 0.23889049, 0.23464356, 0.23036719, 0.22606925,
#        0.2217576 , 0.21744012, 0.21312467, 0.20881912, 0.20453133,
#        0.20026917, 0.1960405 , 0.19185321, 0.18771514, 0.18363418,
#        0.17961818, 0.17567502, 0.17181255, 0.16803866, 0.1643612 ,
#        0.16078804, 0.15732705, 0.15398609, 0.15077304, 0.14769576,
#        0.14476212, 0.14197998, 0.13935721, 0.13690169, 0.13462126,
#        0.13252382, 0.13061721, 0.12890931, 0.12740798, 0.12612109,
#        0.12505652, 0.12422211, 0.12362576, 0.12327658, 0.12318881,
#        0.12337794, 0.12385946, 0.12464888, 0.12576169, 0.12721338,
#        0.12901945, 0.1311954 , 0.13375672, 0.13671891, 0.14009746,
#        0.14390786, 0.14816563, 0.15288624, 0.1580852 , 0.163778  ,
#        0.16998014, 0.17670712, 0.18397442, 0.19179754, 0.20019199,
#        0.20917325, 0.21875683, 0.22895821, 0.2397929 , 0.25127639,
#        0.26342417])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(fine_doys, b_spline, label='SOS NDVI Values')
plt.scatter(doys, ndvi_values, color='red', label='Original NDVI Values', s=10)

# %%
doys
# Out:
# array([106, 108, 156, 161, 173, 201, 206, 221, 223, 273, 296, 301])

# %%
max_ndvi_doy, max_ndvi_value = find_max(fine_doys, b_spline, THRESH_END)
max_ndvi_doy, max_ndvi_value
# Out:
# (106, 0.31748364817251246)

# %%
fine_doys
# Out:
# array([106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#        119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131,
#        132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144,
#        145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157,
#        158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170,
#        171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183,
#        184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196,
#        197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209,
#        210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222,
#        223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235,
#        236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248,
#        249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261,
#        262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274,
#        275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287,
#        288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300,
#        301])

# %%
max_ndvi_doy
# Out:
# 106

# %%
fine_doys, b_spline = filter_to_range_between_minima(fine_doys, b_spline, max_ndvi_doy)
fine_doys, b_spline
# Out:
# filter_to_range_between_minima mask_sos [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False] mask_eos [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]
# filter_to_range_between_minima filtered_doys_sos []
# filter_to_range_between_minima filtered_b_spline_sos []
# filter_to_range_between_minima filtered_doys_eos [107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124
#  125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142
#  143 144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160
#  161 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178
#  179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196
#  197 198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214
#  215 216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232
#  233 234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250
#  251 252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268
#  269 270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286
#  287 288 289 290 291 292 293 294 295 296 297 298 299 300 301]
# filter_to_range_between_minima filtered_b_spline_eos [0.31111274 0.30492452 0.2989169  0.29308782 0.28743521 0.28195698
#  0.27665108 0.27151543 0.26654796 0.26174659 0.25710926 0.25263389
#  0.24831841 0.24416075 0.24015884 0.2363106  0.23261397 0.22906687
#  0.22566722 0.22241297 0.21930203 0.21633234 0.21350182 0.21080841
#  0.20825002 0.20582459 0.20353004 0.20136431 0.19932533 0.19741101
#  0.19561929 0.1939481  0.19239536 0.19095901 0.18963697 0.18842717
#  0.18732754 0.186336   0.18545049 0.18466893 0.18398926 0.18340939
#  0.18292726 0.18254079 0.18224792 0.18204658 0.18193468 0.18191016
#  0.18197095 0.18211497 0.18234016 0.18264444 0.18302574 0.18348198
#  0.18401111 0.18461103 0.18527969 0.18601501 0.18681493 0.18767735
#  0.18860023 0.18958147 0.19061902 0.1917108  0.19285474 0.19404877
#  0.19529081 0.19657879 0.19791065 0.1992843  0.20069769 0.20214873
#  0.20363535 0.20515549 0.20670706 0.20828801 0.20989625 0.21152972
#  0.21318634 0.21486405 0.21656076 0.21827442 0.22000294 0.22174425
#  0.22349629 0.22525698 0.22702425 0.22879603 0.23057024 0.23234482
#  0.23411769 0.23588678 0.23765002 0.23940534 0.24115066 0.24288391
#  0.24460303 0.24630594 0.24799056 0.24965484 0.2512969  0.25291574
#  0.25451056 0.25608058 0.25762499 0.259143   0.26063382 0.26209665
#  0.26353069 0.26493516 0.26630925 0.26765217 0.26896313 0.27024134
#  0.27148598 0.27269629 0.27387144 0.27501067 0.27611316 0.27717812
#  0.27820476 0.27919228 0.28013989 0.2810468  0.2819122  0.28273531
#  0.28351532 0.28425146 0.28494291 0.28558888 0.28618858 0.28674122
#  0.287246   0.28770213 0.2881088  0.28846523 0.28877062 0.28902418
#  0.2892251  0.28937261 0.28946589 0.28950416 0.28948663 0.28941248
#  0.28928095 0.28909121 0.28884249 0.28853399 0.28816491 0.28773446
#  0.28724184 0.28668626 0.28606693 0.28538304 0.2846338  0.28381842
#  0.28293611 0.28198607 0.2809675  0.27987961 0.2787216  0.27749268
#  0.27619206 0.27481894 0.27337253 0.27185202 0.27025663 0.26858556
#  0.26683802 0.2650132  0.26311033 0.26112859 0.2590672  0.25692537
#  0.25470229 0.25239717 0.25000922 0.24753764 0.24498163 0.24234042
#  0.23961318 0.23679915 0.23389751 0.23090747 0.22782824 0.22465903
#  0.22139903 0.21804746 0.21460351 0.2110664  0.20743534 0.20370951
#  0.19988813 0.19597041 0.19195555]
# filter_to_range_between_minima index_sos None
# filter_to_range_between_minima index_eos 47
# filter_to_range_between_minima original_index_sos 0
# filter_to_range_between_minima original_index_eos 48
# (array([106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#         119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131,
#         132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144,
#         145, 146, 147, 148, 149, 150, 151, 152, 153, 154]),
#  array([0.31748365, 0.31111274, 0.30492452, 0.2989169 , 0.29308782,
#         0.28743521, 0.28195698, 0.27665108, 0.27151543, 0.26654796,
#         0.26174659, 0.25710926, 0.25263389, 0.24831841, 0.24416075,
#         0.24015884, 0.2363106 , 0.23261397, 0.22906687, 0.22566722,
#         0.22241297, 0.21930203, 0.21633234, 0.21350182, 0.21080841,
#         0.20825002, 0.20582459, 0.20353004, 0.20136431, 0.19932533,
#         0.19741101, 0.19561929, 0.1939481 , 0.19239536, 0.19095901,
#         0.18963697, 0.18842717, 0.18732754, 0.186336  , 0.18545049,
#         0.18466893, 0.18398926, 0.18340939, 0.18292726, 0.18254079,
#         0.18224792, 0.18204658, 0.18193468, 0.18191016]))

# %%
left_model, right_model = fit_linear_regression(fine_doys, b_spline, max_ndvi_doy)
left_model, right_model
# Out:
# (None, LinearRegression())

# %%
fine_doys.size, max_ndvi_doy, b_spline.size
# Out:
# (49, 106, 49)

# %%
fine_doys < max_ndvi_doy
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %%
#### MAJOR CHANGOE !! b_spline instead of ndvi_values  !!!
divisor = 0
if np.any(fine_doys < max_ndvi_doy):
    base_sos = min(b_spline[fine_doys < max_ndvi_doy])
else:
    base_sos_ = 0
    divisor += 1

if np.any(fine_doys > max_ndvi_doy):
    base_eos = min(b_spline[fine_doys > max_ndvi_doy])
else:
    base_eos = 0
    divisor += 1

# %%
base =  (base_sos + base_eos)/ divisor if divisor != 0 else None

# %%
amplitude = max_ndvi_value - base if base is not None else None

# %%
overall_relative_amplitude = calculate_relative_amplitude(ndvi_values)

# %%
sos_eos_dict = calculate_sos_eos(fine_doys,  b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude)
# Out:
#  sos_mask = fine_doys < max_ndvi_doy [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# eos_mask = fine_doys > max_ndvi_doy [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# sos_doys []
# eos_doys [107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124
#  125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142
#  143 144 145 146 147 148 149 150 151 152 153 154]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 sos_eos_dict = calculate_sos_eos(fine_doys,  b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude)
#
# Cell In[14], line 125, in calculate_sos_eos(fine_doys, b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude)
#     112     relative_amplitude_doy_eos = np.nan
#     113     relative_amplitude_doy_eos_old = np.nan
#     115 return {
#     116     'seasonal_amplitude': convert_to_serializable(seasonal_amplitude) if np.any(seasonal_amplitude) else None,
#     117     'len_sos_ndvi_values': convert_to_serializable(len_sos_ndvi_values) if np.any(len_sos_ndvi_values) else None,
#     118     'len_eos_ndvi_values': convert_to_serializable(len_eos_ndvi_values) if np.any(len_eos_ndvi_values) else None,
#     119     'sos_mask': list(convert_to_serializable(sos_mask)) if np.any(sos_mask) else None,
#     120     'eos_mask': list(convert_to_serializable(eos_mask)) if np.any(eos_mask) else None,
#     121     'sos_doys': list(convert_to_serializable(sos_doys)) if np.any(sos_doys) else None,
#     122     'eos_doys': list(convert_to_serializable(eos_doys)) if np.any(eos_doys) else None,
#     123     'sos_ndvi_values': list(convert_to_serializable(sos_ndvi_values)) if np.any(sos_ndvi_values) else None,
#     124     'eos_ndvi_values': list(convert_to_serializable(eos_ndvi_values)) if np.any(eos_ndvi_values) else None,
# --> 125     'sos_threshold': convert_to_serializable(threshold_sos) if np.any(threshold_sos) else None,
#     126     'sos_median_ndvi': convert_to_serializable(median_ndvi_sos) if np.any(median_ndvi_sos) else None,
#     127     'sos_median_diff': list(convert_to_serializable(sos_median_diff)) if np.any(sos_median_diff) else None,
#     128     'sos_first_of_slope_doy': convert_to_serializable(first_of_slope10_sos2_doy) if np.any(first_of_slope10_sos2_doy) else None,
#     129     'sos_median_of_slope_doy': convert_to_serializable(median_of_slope_sos_doy) if np.any(median_of_slope_sos_doy) else None,
#     130     'sos_seasonal_amplitude_doy': convert_to_serializable(seasonal_amplitude_doy_sos) if np.any(seasonal_amplitude_doy_sos) else None,
#     131     'sos_relative_amplitude_doy': convert_to_serializable(relative_amplitude_doy_sos) if np.any(relative_amplitude_doy_sos) else None,
#     132     'sos_relative_amplitude_doy_old': convert_to_serializable(relative_amplitude_doy_sos_old) if np.any(relative_amplitude_doy_sos_old) else None,
#     133     'eos_threshold': convert_to_serializable(threshold_eos) if np.any(threshold_eos) else None,
#     134     'eos_median_ndvi': convert_to_serializable(median_ndvi_eos) if np.any(median_ndvi_eos) else None,
#     135     'eos_median_diff': list(convert_to_serializable(eos_median_diff)) if np.any(eos_median_diff) else None,
#     136     'eos_first_of_slope_doy': convert_to_serializable(first_of_slope10_eos2_doy) if np.any(first_of_slope10_eos2_doy) else None,
#     137     'eos_median_of_slope_doy': convert_to_serializable(median_of_slope_eos_doy) if np.any(median_of_slope_eos_doy) else None,
#     138     'eos_seasonal_amplitude_doy': convert_to_serializable(seasonal_amplitude_doy_eos) if np.any(seasonal_amplitude_doy_eos) else None,
#     139     'eos_relative_amplitude_doy': convert_to_serializable(relative_amplitude_doy_eos) if np.any(relative_amplitude_doy_eos) else None,
#     140     'eos_relative_amplitude_doy_old': convert_to_serializable(relative_amplitude_doy_eos_old) if np.any(relative_amplitude_doy_eos_old) else None,
#     141 }
#
# UnboundLocalError: cannot access local variable 'threshold_sos' where it is not associated with a value

# %%
# new amplitude calculation: NDVI max - (Eos Min + Sos Min / 2)





overall_relative_amplitude = calculate_relative_amplitude(ndvi_values)


sos_eos_dict = calculate_sos_eos(fine_doys,  b_spline, base, amplitude, max_ndvi_doy, max_ndvi_value, overall_relative_amplitude)
print('sos_eos_dict 1: ', sos_eos_dict)




sos_eos_dict.update({'row': LOAD_MIN_ROW + row, 
                    'col': LOAD_MIN_COL + col, 
                    'org_ndvi_values': list(ndvi_values), 
                    'org_ndvi_doys': list(doys),
                    'min_doy': convert_to_serializable(min_doy), 
                    'max_doy': convert_to_serializable(max_doy), 
                    'max_ndvi_doy': convert_to_serializable(max_ndvi_doy), 
                    'max_ndvi_value': convert_to_serializable(max_ndvi_value),
                    'fine_doys': list(fine_doys),
                    'b_spline': list(b_spline),
                    'base': convert_to_serializable(base),
                'amplitude': convert_to_serializable(amplitude),
                'overall_relative_amplitude': convert_to_serializable(overall_relative_amplitude),
                'left_model': left_model.get_params() if left_model is not None else None,
                'right_model': right_model.get_params() if right_model is not None else None,
                'left_model_coef': left_model.coef_[0] if left_model is not None else None,
                'right_model_coef': right_model.coef_[0] if right_model is not None else None,
                'left_model_intercept': left_model.intercept_ if left_model is not None else None,
                'right_model_intercept': right_model.intercept_ if right_model is not None else None,
                })
print('sos_eos_dict after update: ', sos_eos_dict)
return sos_eos_dict

# %%
# Out:
# Start processing ./S2_clip_new/
# Loading NDVI stack from ./S2_clip_new/
# process_pixel  0 0 [0.32519424 0.32625085 0.13020372 0.13749816 0.17107332 0.28943628
#  0.28671557 0.32630885 0.31999999 0.09559111 0.22640292 0.25859156] [106 108 156 161 173 201 206 221 223 273 296 301] 1
# isnan mask (should not all be True) [False False False False False False False False False False False False]
# no ndvi values are nan
# min doy: 106 max doy: 301
# tck_spline (array([106., 106., 106., 106., 206., 301., 301., 301., 301.]), array([0.31748365, 0.10205244, 0.28240577, 0.32063924, 0.19195555,
#        0.        , 0.        , 0.        , 0.        ]), 3)
# max_ndvi_doy, max_ndvi_value 106 0.31748364817251246
# filter_to_range_between_minima mask_sos [ True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False] mask_eos [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]
# filter_to_range_between_minima filtered_doys_sos [106]
# filter_to_range_between_minima filtered_b_spline_sos [0.31748365]
# filter_to_range_between_minima filtered_doys_eos [106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123
#  124 125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141
#  142 143 144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159
#  160 161 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177
#  178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195
#  196 197 198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213
#  214 215 216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231
#  232 233 234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249
#  250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267
#  268 269 270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285
#  286 287 288 289 290 291 292 293 294 295 296 297 298 299 300 301]
# filter_to_range_between_minima filtered_b_spline_eos [0.31748365 0.31111274 0.30492452 0.2989169  0.29308782 0.28743521
#  0.28195698 0.27665108 0.27151543 0.26654796 0.26174659 0.25710926
#  0.25263389 0.24831841 0.24416075 0.24015884 0.2363106  0.23261397
#  0.22906687 0.22566722 0.22241297 0.21930203 0.21633234 0.21350182
#  0.21080841 0.20825002 0.20582459 0.20353004 0.20136431 0.19932533
#  0.19741101 0.19561929 0.1939481  0.19239536 0.19095901 0.18963697
#  0.18842717 0.18732754 0.186336   0.18545049 0.18466893 0.18398926
#  0.18340939 0.18292726 0.18254079 0.18224792 0.18204658 0.18193468
#  0.18191016 0.18197095 0.18211497 0.18234016 0.18264444 0.18302574
#  0.18348198 0.18401111 0.18461103 0.18527969 0.18601501 0.18681493
#  0.18767735 0.18860023 0.18958147 0.19061902 0.1917108  0.19285474
#  0.19404877 0.19529081 0.19657879 0.19791065 0.1992843  0.20069769
#  0.20214873 0.20363535 0.20515549 0.20670706 0.20828801 0.20989625
#  0.21152972 0.21318634 0.21486405 0.21656076 0.21827442 0.22000294
#  0.22174425 0.22349629 0.22525698 0.22702425 0.22879603 0.23057024
#  0.23234482 0.23411769 0.23588678 0.23765002 0.23940534 0.24115066
#  0.24288391 0.24460303 0.24630594 0.24799056 0.24965484 0.2512969
#  0.25291574 0.25451056 0.25608058 0.25762499 0.259143   0.26063382
#  0.26209665 0.26353069 0.26493516 0.26630925 0.26765217 0.26896313
#  0.27024134 0.27148598 0.27269629 0.27387144 0.27501067 0.27611316
#  0.27717812 0.27820476 0.27919228 0.28013989 0.2810468  0.2819122
#  0.28273531 0.28351532 0.28425146 0.28494291 0.28558888 0.28618858
#  0.28674122 0.287246   0.28770213 0.2881088  0.28846523 0.28877062
#  0.28902418 0.2892251  0.28937261 0.28946589 0.28950416 0.28948663
#  0.28941248 0.28928095 0.28909121 0.28884249 0.28853399 0.28816491
#  0.28773446 0.28724184 0.28668626 0.28606693 0.28538304 0.2846338
#  0.28381842 0.28293611 0.28198607 0.2809675  0.27987961 0.2787216
#  0.27749268 0.27619206 0.27481894 0.27337253 0.27185202 0.27025663
#  0.26858556 0.26683802 0.2650132  0.26311033 0.26112859 0.2590672
#  0.25692537 0.25470229 0.25239717 0.25000922 0.24753764 0.24498163
#  0.24234042 0.23961318 0.23679915 0.23389751 0.23090747 0.22782824
#  0.22465903 0.22139903 0.21804746 0.21460351 0.2110664  0.20743534
#  0.20370951 0.19988813 0.19597041 0.19195555]
# filter_to_range_between_minima index_sos 0
# filter_to_range_between_minima index_eos 48
# filter_to_range_between_minima original_index_sos 0
# filter_to_range_between_minima original_index_eos 48
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 process_stack('./S2_clip_new/')
#
# Cell In[20], line 28, in process_stack(input_dir)
#      25 for col in range(num_cols):
#      26     if mask[row, col]:
#      27         # try:
# ---> 28         sos_eos_dict = process_pixel(row, col, ndvi_stack[:, row, col], doys, num_cols)
#      29         # print('sos_eos_dict', sos_eos_dict)
#      30         with open(os.path.join(output_dir, f'S2_{LOAD_MIN_ROW + row}_{LOAD_MIN_COL + col}.py'), 'a') as f:
#
# Cell In[24], line 48, in process_pixel(row, col, ndvi_values, doys, num_cols)
#      43 left_model, right_model = fit_linear_regression(fine_doys, b_spline, max_ndvi_doy)
#      44 # base = calculate_base(left_model, right_model)
#      45 # amplitude = max_ndvi_value - base
#      46
#      47 # new amplitude calculation: NDVI max - (Eos Min + Sos Min / 2)
# ---> 48 base = (min(ndvi_values[fine_doys < max_ndvi_doy]) + min(ndvi_values[fine_doys > max_ndvi_doy])) / 2
#      49 amplitude = max_ndvi_value - base
#      53 overall_relative_amplitude = calculate_relative_amplitude(ndvi_values)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 12 but corresponding boolean dimension is 49

# %%
def filter_to_range_between_minima(fine_doys, b_spline, max_ndvi_doy):
    
    mask_sos = fine_doys < max_ndvi_doy
    mask_eos = fine_doys > max_ndvi_doy
    
    filtered_doys_sos = fine_doys[mask_sos]
    index_sos = np.argmin(b_spline[mask_sos])
    index_eos = np.argmin(b_spline[mask_eos])
    # print('b_spline[mask_eos]', b_spline[mask_eos])
    # print('b_spline min', np.min(b_spline[mask_sos]))
    b_spline_new = b_spline[index_sos:(index_eos+1)]
    fine_doys_new = fine_doys[index_sos:(index_eos+1)]
    # print('index_sos', index_sos, 'SOS doy',fine_doys[index_sos])
    # print('index_eos', index_eos, 'Eos doy', fine_doys[index_eos])
    # print('fine_doys after', fine_doys_new)
    

    # min_ndvi_doy_sos = filtered_doys_sos[np.argmin(filtered_ndvi_values_sos)]
    
    # filtered_doys_eos = fine_doys[mask_eos]
    
    
    # filtered_ndvi_values_eos = b_spline[mask_eos]
    
    
    # min_ndvi_doy_eos = filtered_doys_eos[np.argmin(filtered_ndvi_values_eos)]
    
    return fine_doys_new, b_spline_new

# %%
fine_doys = np.array([100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200])
b_spline = np.array([0.3, 0.2, 0.4, 0.45, 0.5, 0.6, 0.55, 0.5, 0.45, 0.3, 0.35])
max_ndvi_doy = 150

fine_doys_new, b_spline_new = filter_to_range_between_minima(fine_doys, b_spline, max_ndvi_doy)

print('Fine doys new:', fine_doys_new)
print('B spline new:', b_spline_new)
# Out:
# filter_to_range_between_minima mask_sos [ True  True  True  True  True  True False False False False False] mask_eos [False False False False False  True  True  True  True  True  True]
# filter_to_range_between_minima filtered_doys_sos [100 110 120 130 140 150]
# filter_to_range_between_minima filtered_b_spline_sos [0.3  0.2  0.4  0.45 0.5  0.6 ]
# filter_to_range_between_minima filtered_doys_eos [150 160 170 180 190 200]
# filter_to_range_between_minima filtered_b_spline_eos [0.6  0.55 0.5  0.45 0.3  0.35]
# filter_to_range_between_minima index_sos 1
# filter_to_range_between_minima index_eos 4
# filter_to_range_between_minima original_index_sos 1
# filter_to_range_between_minima original_index_eos 9
# Fine doys new: [110 120 130 140 150 160 170 180 190]
# B spline new: [0.2  0.4  0.45 0.5  0.6  0.55 0.5  0.45 0.3 ]
