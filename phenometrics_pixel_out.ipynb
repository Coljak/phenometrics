# %% [markdown]
# For Analysis of Calculations
# Run this script first!
# It will produce folders named \<iso-date\>_analysis_output_vx.py
# The calculations are the same as in phenometrics.py. The output of this script is the used in the script
# phenometrics_pixel_to_graph.ipynb.

# %%
import os
import numpy as np
import pandas as pd
import concurrent.futures
import rasterio
import json
from scipy.interpolate import splrep, BSpline
from sklearn.linear_model import LinearRegression
from datetime import datetime
from phenometrics import find_max, calculate_relative_amplitude, process_pixel, calculate_sos_eos, calculate_relative_amplitude
import matplotlib.pyplot as plt

# %%
LOAD_MIN_COL = 705
LOAD_MAX_COL = LOAD_MIN_COL + 1
LOAD_MIN_ROW = 436
LOAD_MAX_ROW = 443

# needs to be set here for the plotting - the same constant in phenometrics.py has no effect
THRESHOLD_ = 90

# %%
def load_ndvi_stack(directory, filter_threshold=THRESHOLD_):
    """
    Load NDVI stack from a directory containing NDVI images.
    The threshold is set from the constants if not set manually to an int between 0 and 365.
    A two dimensional mask is returned that is true for all pixels that hold at least one value 
    """
    print('Loading NDVI stack from', directory)
    # TODO: shouldn't the first dataset below the threshold be taken into consideration?

    file_paths = sorted([os.path.join(directory, fp) for fp in os.listdir(directory) if fp.endswith('.tif')])
    
    def sort_by_doy(file_paths):
        fps = np.array(file_paths)
        fp_doys = np.array([os.path.basename(fp).split('_')[-2].split('.')[0] for fp in fps])
        sorted_indices = np.argsort(fp_doys)
        return fps[sorted_indices]
    
    file_paths = sort_by_doy(file_paths)
    
    doys = np.array([int(os.path.basename(fp).split('_')[-2].split('.')[0]) for fp in file_paths], dtype=np.int64)
    
    if filter_threshold is not None:
        file_paths = [fp for fp in file_paths if int(os.path.basename(fp).split('_')[-2].split('.')[0]) >= filter_threshold]
        doys = np.array([int(os.path.basename(fp).split('_')[-2].split('.')[0]) for fp in file_paths], dtype=np.int64)

    ndvi_stack = []
    mask_stack = []
       
    for fp in file_paths:
        with rasterio.open(fp) as dataset:
            ndvi_data = dataset.read(1).astype(np.float64)
            ndvi_stack.append(ndvi_data[LOAD_MIN_ROW:LOAD_MAX_ROW, LOAD_MIN_COL:LOAD_MAX_COL])
            # ndvi_stack.append(ndvi_data)
            
            mask_stack.append(np.isnan(ndvi_data[LOAD_MIN_ROW:LOAD_MAX_ROW, LOAD_MIN_COL:LOAD_MAX_COL]))
    with rasterio.open(file_paths[0]) as dataset:
        meta = dataset.meta

    ndvi_stack = np.array(ndvi_stack)
    mask_stack = np.array(mask_stack)

    valid_image_area_mask = ~np.any(mask_stack, axis=0)
    if len(doys) < 3:
        raise ValueError(f'Not enough images in the stack (less than 3!) in directory {directory} with threshold {filter_threshold}')
    
    return ndvi_stack, doys, valid_image_area_mask, meta

# %%
def convert_to_serializable(obj):
    if obj is np.nan:
        return None
    if isinstance(obj, np.generic):
        return obj.item()
    return obj

# %%
def serialize_sos_eos_dict(sos_eos_dict):
    serialized_dict = {
        'pixel_idx': sos_eos_dict['pixel_idx'], 
        'row': sos_eos_dict['row'],  
        'col': sos_eos_dict['col'],  
        'smooth': sos_eos_dict['smooth'],
        'threshold_start': sos_eos_dict['threshold_start'],
        'threshold_end': sos_eos_dict['threshold_end'],

        'org_ndvi_doys': list(convert_to_serializable(sos_eos_dict['org_ndvi_doys'])),  
        'org_ndvi_values': list(convert_to_serializable(sos_eos_dict['org_ndvi_values'])), 
    
        'sos_first_of_slope_doy': convert_to_serializable(sos_eos_dict['sos_first_of_slope']), 
        'sos_median_of_slope_doy': convert_to_serializable(sos_eos_dict['sos_median_of_slope']),
        'sos_seasonal_amplitude_doy': convert_to_serializable(sos_eos_dict['sos_seasonal_amplitude']), 
        'sos_seasonal_amplitude': convert_to_serializable(sos_eos_dict['sos_seasonal_amplitude_ndvi']),
        'sos_relative_amplitude_doy': convert_to_serializable(sos_eos_dict['sos_relative_amplitude']),
        'sos_relative_amplitude': convert_to_serializable(sos_eos_dict['sos_relative_amplitude_ndvi']),
        'sos_relative_amplitude_old_doy': convert_to_serializable(sos_eos_dict['sos_relative_amplitude_old']), 

        'eos_first_of_slope_doy': convert_to_serializable(sos_eos_dict['eos_first_of_slope']), 
        'eos_median_of_slope_doy': convert_to_serializable(sos_eos_dict['eos_median_of_slope']), 
        'eos_seasonal_amplitude_doy': convert_to_serializable(sos_eos_dict['eos_seasonal_amplitude']), 
        'eos_seasonal_amplitude': convert_to_serializable(sos_eos_dict['eos_seasonal_amplitude_ndvi']),
        'eos_relative_amplitude_doy': convert_to_serializable(sos_eos_dict['eos_relative_amplitude']),
        'eos_relative_amplitude': convert_to_serializable(sos_eos_dict['eos_relative_amplitude_ndvi']),
        'eos_relative_amplitude_old_doy': convert_to_serializable(sos_eos_dict['eos_relative_amplitude_old']), 
    

        'sos_doys': list(convert_to_serializable(sos_eos_dict['sos_doys'])) if np.any(sos_eos_dict['sos_doys']) else None,
        'eos_doys': list(convert_to_serializable(sos_eos_dict['eos_doys'])) if np.any(sos_eos_dict['eos_doys']) else None,
        'sos_ndvi_values': list(convert_to_serializable(sos_eos_dict['sos_ndvi_values'])) if np.any(sos_eos_dict['sos_ndvi_values']) else None,
        'eos_ndvi_values': list(convert_to_serializable(sos_eos_dict['eos_ndvi_values'])) if np.any(sos_eos_dict['eos_ndvi_values']) else None,
        'amplitude': convert_to_serializable(sos_eos_dict['amplitude']) if np.any(sos_eos_dict['amplitude']) else None,
        'max_ndvi_doy': convert_to_serializable(sos_eos_dict['max_ndvi_doy']),
        'max_ndvi_value': convert_to_serializable(sos_eos_dict['max_ndvi_value']),
        'fine_doys': list(convert_to_serializable(sos_eos_dict['fine_doys'])),
        'base': convert_to_serializable(sos_eos_dict['base']), 
        'overall_relative_amplitude': convert_to_serializable(sos_eos_dict['overall_relative_amplitude']),
       
    }
    return serialized_dict

# %%
def plot_ndvi_values(sos_eos_dict):    
    plt.figure(figsize=(12, 6))
    plt.plot(sos_eos_dict['sos_doys'], sos_eos_dict['sos_ndvi_values'], label='SOS NDVI Values')
    plt.plot(sos_eos_dict['eos_doys'], sos_eos_dict['eos_ndvi_values'], label='EOS NDVI Values')
    try:
        plt.plot(sos_eos_dict['fine_doys'], [sos_eos_dict['seasonal_amplitude'] for x in range(0,len(sos_eos_dict['fine_doys']))], label='Seasonal Amplitude')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['fine_doys'], [sos_eos_dict['base'] for x in range(0,len(sos_eos_dict['fine_doys']))], label='Base')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['fine_doys'], [sos_eos_dict['amplitude'] for x in range(0,len(sos_eos_dict['fine_doys']))], label='Amplitude')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['sos_doys'], [sos_eos_dict['sos_threshold'] for x in range(0,len(sos_eos_dict['sos_doys']))], label='SoS Threshold')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['eos_doys'], [sos_eos_dict['eos_threshold'] for x in range(0,len(sos_eos_dict['eos_doys']))], label='EoS Threshold')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['sos_doys'], [sos_eos_dict['sos_seasonal_amplitude_ndvi'] for x in range(0,len(sos_eos_dict['sos_doys']))], label='SoS Seasonal Amplitude')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['eos_doys'], [sos_eos_dict['eos_seasonal_amplitude_ndvi'] for x in range(0,len(sos_eos_dict['eos_doys']))], label='EoS Seasonal Amplitude')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['sos_doys'], [sos_eos_dict['sos_relative_amplitude_ndvi'] for x in range(0,len(sos_eos_dict['sos_doys']))], label='SoS Relative Amplitude')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['eos_doys'], [sos_eos_dict['eos_relative_amplitude_ndvi'] for x in range(0,len(sos_eos_dict['eos_doys']))], label='EoS Relative Amplitude')
    except:
        pass
    try:
        plt.plot(sos_eos_dict['sos_doys'], [sos_eos_dict['sos_median_ndvi'] for x in range(0,len(sos_eos_dict['sos_doys']))], label='SoS Median NDVI')
    except:
        pass
    try:  
        plt.plot(sos_eos_dict['eos_doys'], [sos_eos_dict['eos_median_ndvi'] for x in range(0,len(sos_eos_dict['eos_doys']))], label='EoS Median NDVI')
    except:
        pass
    try: 
        plt.plot(sos_eos_dict['fine_doys'], [sos_eos_dict['overall_relative_amplitude'] for x in range(0,len(sos_eos_dict['fine_doys']))], label='Relative Amplitude')
    except:
        pass
    try:
        lin_regression_values_sos = sos_eos_dict['left_model_coef'] * np.array(sos_eos_dict['sos_doys']) + sos_eos_dict['left_model_intercept']
        plt.plot(sos_eos_dict['sos_doys'], lin_regression_values_sos, label='Linear Regression SoS')
    except:
        pass
    try:
        lin_regression_values_eos = sos_eos_dict['right_model_coef'] * np.array(sos_eos_dict['eos_doys']) + sos_eos_dict['right_model_intercept']
        plt.plot(sos_eos_dict['eos_doys'], lin_regression_values_eos, label='Linear Regression EoS')
    except:
        pass
        
    plt.scatter(sos_eos_dict['org_ndvi_doys'], sos_eos_dict['org_ndvi_values'], color='red', label='Original NDVI Values', s=10)
    try:
        plt.axvline(x=sos_eos_dict['eos_first_of_slope_doy'], color='black', linestyle='--', label='eos_first_of_slope_doy')
    except:
        pass
    try:    
        plt.axvline(x=sos_eos_dict['sos_first_of_slope_doy'], color='black', linestyle='--', label='sos_first_of_slope_doy')
    except:
        pass
    try:    
        plt.axvline(x=sos_eos_dict['sos_median_of_slope_doy'], color='purple', linestyle='--', label='sos_median_of_slope_doy')
    except:
        pass
    try:    
        plt.axvline(x=sos_eos_dict['eos_median_of_slope_doy'], color='purple', linestyle='--', label='eos_median_of_slope_doy')
    except:
        pass
    try:    
        plt.axvline(x=sos_eos_dict['sos_relative_amplitude_doy'], color='blue', linestyle='--', label='sos_relative_amplitude_doy')
    except:
        pass
    try:    
        plt.axvline(x=sos_eos_dict['eos_relative_amplitude_doy'], color='blue', linestyle='--', label='eos_relative_amplitude_doy')
    except:
        pass
    try:    
        plt.axvline(x=sos_eos_dict['max_ndvi_doy'], color='black', linestyle='-', label='Max NDVI')
    except:
        pass

    plt.scatter(sos_eos_dict['max_ndvi_doy'], sos_eos_dict['max_ndvi_value'], color='green', label='Max NDVI', s=30)



    plt.annotate(f'Max NDVI: {sos_eos_dict['max_ndvi_doy']}', xy=(sos_eos_dict['max_ndvi_doy'], 0), xycoords=('data', 'axes fraction'),
             xytext=(-20, -10), textcoords='offset points', ha='center', va='top', fontsize=9, color='black', rotation=45)


    plt.xlabel('DOY')
    plt.ylabel('NDVI Value')
    plt.title(f'Row {sos_eos_dict["row"]}, Column {sos_eos_dict["col"]}, SMOOTH: {sos_eos_dict["smooth"]}, THRESHOLD: {sos_eos_dict["threshold_start"]}, THES_END: {sos_eos_dict["threshold_end"]}')
    # Adding the legend outside the plot
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

    # Adjusting the layout to make room for the legend
    plt.tight_layout()
    plt.show()

# %%
def process_stack(input_dir):
    """Main function to process NDVI data."""
    print(f'Start processing {input_dir}')
    start = datetime.now()
    current_date = datetime.now().date().isoformat()

    def make_directory(input_dir, counter=1):
        output_dir = os.path.join(os.path.dirname(os.path.dirname(input_dir)), f'{current_date}_analysis_output_v{counter}')
        if os.path.exists(output_dir):
            return make_directory(input_dir, counter + 1)
        else:
            os.makedirs(output_dir)
        return output_dir

    output_dir = make_directory(input_dir)

   
    ndvi_stack, doys, mask, meta = load_ndvi_stack(input_dir)
    num_rows, num_cols = ndvi_stack[0].shape
    # print(input_dir, ndvi_stack[0].shape)
    # Ensure sos_eos_data has enough depth to store all keys from the dictionary
        
    for row in range(num_rows):
        for col in range(num_cols):
            if mask[row, col]:
                # try:  
                sos_eos_dict = process_pixel(row, col, ndvi_stack[:, row, col], doys, num_cols)
                sos_eos_dict['row'] = LOAD_MIN_ROW + row
                sos_eos_dict['col'] = LOAD_MIN_COL + col
                sos_eos_dict.update({
                    'org_ndvi_doys': doys,
                    'org_ndvi_values': ndvi_stack[:, row, col],
                })
                # print('sos_eos_dict', sos_eos_dict)
                serialized_dict = serialize_sos_eos_dict(sos_eos_dict)
                plot_ndvi_values(serialized_dict)
                
                with open(os.path.join(output_dir, f'S2_{LOAD_MIN_ROW + row}_{LOAD_MIN_COL + col}.py'), 'a') as f:
                    f.write('ndvi_dict = {\n')
                    for key, value in serialized_dict.items():
                        f.write(f'    "{key}": {value},\n')   
                    f.write('}\n')
                # except Exception as e:
                #     print(f'Error processing pixel {row}, {col}: {e}')
                #     continue

# %%
process_stack('./S2_clip_new/')
# Out:
# Start processing ./S2_clip_new/
# Loading NDVI stack from ./S2_clip_new/
# sos_diff [-0.02027245 -0.02009475 -0.01971481 -0.01913808 -0.01836999 -0.01741598
#  -0.01628148 -0.01497193 -0.01349276 -0.01184943 -0.01004735 -0.00809197
#  -0.00598872 -0.00374305 -0.00136038  0.00115384  0.00379417  0.00655519
#   0.00943146  0.01241753  0.01550797  0.01869735  0.02198022  0.02535116
#   0.02880471  0.03233546  0.03593795  0.03960676  0.04333644  0.04712156
#   0.05095669  0.05483638  0.0587552   0.06270771  0.06668847  0.07069206
#   0.07471302  0.07874593  0.08278535  0.08682584  0.09086197  0.09488829
#   0.09889937  0.10288977  0.10685407  0.11078681  0.11468256  0.1185359
#   0.12234137  0.12609354  0.12978698  0.13341625  0.13697591  0.14046053
#   0.14386466  0.14718288  0.15040974  0.15353981  0.15656766  0.15948783
#   0.1622949   0.16498181  0.167535    0.16993928  0.17217948  0.1742404
#   0.17610687  0.1777637   0.17919571  0.18038771  0.18132453  0.18199098
#   0.18237187]
# sos_diff [-0.01893099 -0.01869913 -0.0181927  -0.01740834 -0.01634266 -0.0149923
#  -0.01335388 -0.01142402 -0.00919935 -0.00667943 -0.0038756  -0.00080212
#   0.00252673  0.00609667  0.00989209  0.013892    0.01807406  0.02241596
#   0.02689535  0.03148991  0.0361773   0.0409352   0.04574126  0.05057317
#   0.05540858  0.06022517  0.06500355  0.06973612  0.0744182   0.07904513
#   0.08361225  0.08811488  0.09254838  0.09690807  0.10118928  0.10538735
#   0.10949762  0.11351543  0.1174361   0.12125497  0.12496738  0.12856866
#   0.13205414  0.13541917  0.13865908  0.14176919  0.14474486  0.1475814
#   0.15027417  0.15281848  0.15520969  0.15744311  0.15951409  0.16141797
